# %% [markdown]
# <a href="https://colab.research.google.com/github/velizhask/PemrosesanBahasaAlami-nlp/blob/main/PBA_Pertemuan_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Pengenalan PBA dan Aplikasi di Dunia Nyata**
# ##PERTEMUAN 1
#
# # ---
#
# *   Mengambil Data dari platform yang sudah menyediakan dataset yang siap diunduh secara langsung, baik secara manual maupun melalui API resmi, seperti Kaggle
# *   Crawling Data dari platform yang memerlukan akses ke situs web, kemudian mengunduh dan mengolah konten HTML untuk mengekstrak data yang diperlukan, tanpa API atau file download yang sudah tersedia, seperti X

# %% [markdown]
# LIBRARY

# %%
import pandas as pd

# %% [markdown]
# #KAGGLE

# %% [markdown]
# **bold text**
#
# > GOOGLE DRIVE
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !unzip '/content/drive/MyDrive/Colab Notebooks/archive.zip'
# Out:
# Archive:  /content/drive/MyDrive/Colab Notebooks/archive.zip
#   inflating: GojekAppReviewV4.0.0-V4.9.3_Cleaned.csv

# %%
data1= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archive.zip')
data1.head(10)
# Out:
#                   userName                                            content  \
# 0                Yuga Edit                            akun gopay saya di blok
# 1                 ff burik  Lambat sekali sekarang ini bosssku apk gojek g...
# 2  Anisa Suci Rahmayuliani  Kenapa sih dari kemarin sy buka aplikasi gojek...
# 3             naoki yakuza  Baru download gojek dan hape baru trus ditop u...
# 4            Trio Sugianto                                             Mantap
# 5             Arlan Ramlan                                              Bagus
# 6         Slamet Hariyanto                                          Coba dulu
# 7               Hasan Thio                                                 Ok
# 8             RAFI BADZLIN  Gimana ini kak pin saya salah terus padahal ud...
# 9              mariyadi qc  Biar aman kamu tidak bisa pakai gojek Jadi say...
#
#    score                   at appVersion
# 0      1  2022-01-21 10:52:12      4.9.3
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > INPUT INTERNAL
#
# ---

# %%
#Unggah kaggle.json
from google.colab import files
files.upload()

#Set environment variable
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive"

#Ekstrak dataset
# !unzip archive.zip #archive adalah nama file
# Out:
#      <input type="file" id="files-e8ce3932-f41d-4e58-950c-8983ed49c211" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e8ce3932-f41d-4e58-950c-8983ed49c211">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
data2= pd.read_csv('/content/hateXplain.csv')
data2.head()
# Out:
#                        post_id  annotator_id   label target  \
# 0  1179055004553900032_twitter             1  normal    NaN
# 1  1179055004553900032_twitter             2  normal    NaN
# 2  1179055004553900032_twitter             3  normal    NaN
# 3  1179063826874032128_twitter             1  normal    NaN
# 4  1179063826874032128_twitter             2  normal    NaN
#
#                                          post_tokens
# 0  i dont think im getting my baby them white 9 h...
# 1  i dont think im getting my baby them white 9 h...
# 2  i dont think im getting my baby them white 9 h...
# 3  we cannot continue calling ourselves feminists...
# 4  we cannot continue calling ourselves feminists...

# %% [markdown]
# > API COMMAND KAGGLE
#
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# from google.colab import files
# files.upload()  # Ini akan memunculkan prompt untuk mengunggah file 'kaggle.json'

# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json  # Set permission agar file hanya bisa diakses oleh pemilik

# !kaggle datasets download -d dewanakretarta/tokopedia-playstore-reviews
# !unzip tokopedia-playstore-reviews
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dewanakretarta/tokopedia-playstore-reviews
# License(s): MIT
# tokopedia-playstore-reviews.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  tokopedia-playstore-reviews.zip
# replace tokopedia.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: tokopedia.csv

# %%
data3= pd.read_csv('/content/tokopedia.csv')
data3.head(10)
# Out:
#                                reviewId                    userName  \
# 0  1c130054-e298-44ec-8920-e67bb8cc58d5             Uyiderf Uyiderf
# 1  9b7ab32f-f76e-4ef2-9db6-6b9398063fd1               Binti Umaeroh
# 2  825d07f4-416c-4322-a7e2-667b092716ef                 ade suhanda
# 3  960ce4ff-4059-4dff-891b-3d6615d7800f                 Mujahid Ali
# 4  1476bc00-2736-42cb-aed2-f731caaba73a                     Salam M
# 5  887f13d8-1a42-4927-8e7b-b511d2e25b43         Priyanto Wichaksono
# 6  ad8366d2-1cc3-4b79-8f5d-0f5349e62b83                  Rahma Wati
# 7  9000311d-6d64-4586-a785-842ef5adfb12       Franciska Putriarifah
# 8  c12416b8-5dc9-4719-830b-241c1536f21e           Alvina Agustianai
# 9  0e692402-4bd1-4963-aa35-88b5c7e8e38a  Tri Yono (Threelostmemory)
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# ...

# %%
# Cek jumlah data yang didapatkan
bun_data = len(data3)
print(f"Jumlah data dalam dataframe adalah {bun_data}.")
# Out:
# Jumlah data dalam dataframe adalah 199.

# %% [markdown]
# #X

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
twitter_auth_token = 'e89aa6ed69d2f40a56a073bbca730923dec6f38f' # change this auth token

# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Ign:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,031 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,592 kB]
# Hit:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# ...

# %%
# Crawl Data

filename = 'fufufafa.csv'
search_keyword = 'fufufafa since:2024-02-01 until:2024-09-20 lang:id'
limit = 300

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦npm warn deprecated rimraf@3.0.2: Rimraf versions prior to v4 are no longer supported
# ⠦⠧npm warn deprecated inflight@1.0.6: This module is not supported, and leaks memory. Do not use it. Check out lru-cache if you want a good and tested way to coalesce async requests by a key value, which is much more comprehensive and powerful.
# ⠧npm warn deprecated glob@7.2.3: Glob versions prior to v9 are no longer supported
# ⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# ...

# %%
datax = pd.read_csv('/content/tweets-data/fufufafa.csv')
datax.head(15)
# Out:
#     conversation_id_str                      created_at  favorite_count  \
# 0   1836728535333077487  Thu Sep 19 23:59:24 +0000 2024               7
# 1   1836917830492750195  Thu Sep 19 23:58:33 +0000 2024               0
# 2   1836917649672130830  Thu Sep 19 23:57:50 +0000 2024               0
# 3   1836763552033784300  Thu Sep 19 23:57:14 +0000 2024               0
# 4   1836371268687544779  Thu Sep 19 23:56:44 +0000 2024               1
# 5   1836917178567717169  Thu Sep 19 23:55:58 +0000 2024               0
# 6   1836196520934412771  Thu Sep 19 23:55:27 +0000 2024               0
# 7   1836805123965964671  Thu Sep 19 23:53:46 +0000 2024             830
# 8   1836806256092381427  Thu Sep 19 23:53:28 +0000 2024              14
# 9   1836916366223557112  Thu Sep 19 23:52:44 +0000 2024               0
# 10  1836916205782979025  Thu Sep 19 23:52:06 +0000 2024               1
# 11  1836348196903059530  Thu Sep 19 23:52:03 +0000 2024               0
# ...

# %% [markdown]
# Tweets Data Harvest
#
# ---

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1836909365309362263  Thu Sep 19 23:24:55 +0000 2024               0
# 1    1836909302143144429  Thu Sep 19 23:24:40 +0000 2024               0
# 2    1836554634309308748  Thu Sep 19 23:24:15 +0000 2024               0
# 3    1836909033170817114  Thu Sep 19 23:23:36 +0000 2024               0
# 4    1836908544303714784  Thu Sep 19 23:21:39 +0000 2024               0
# ..                   ...                             ...             ...
# 312  1836757887797879220  Thu Sep 19 13:23:00 +0000 2024               1
# 313  1836757886032355705  Thu Sep 19 13:22:59 +0000 2024               0
# 314  1836757838682878435  Thu Sep 19 13:22:48 +0000 2024               0
# 315  1836757713797394682  Thu Sep 19 13:22:18 +0000 2024               0
# 316  1836757668851331103  Thu Sep 19 13:22:08 +0000 2024               0
#
#                                              full_text               id_str  \
# ...

# %%
# Cek jumlah data yang didapatkan
num_tweets = len(df)
print(f"Jumlah data dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah data dalam dataframe adalah 317.

# %% [markdown]
# #KOMPAS

# %%
# Install library yang diperlukan (jika belum terpasang)
# !pip install beautifulsoup4 requests

# %%
import requests
from bs4 import BeautifulSoup

# URL pencarian untuk artikel tentang "pilkada"
url = 'https://www.kompas.com/tag/pilkada'

# Melakukan request ke halaman pencarian Kompas
response = requests.get(url)

# Memastikan bahwa request berhasil
if response.status_code == 200:
    # Parsing HTML dari halaman pencarian
    soup = BeautifulSoup(response.content, 'html.parser')

    # Menyimpan hasil artikel yang diambil
    articles = []

    # Mengambil semua elemen artikel hasil pencarian
    for item in soup.find_all('a', class_='article__link'):
        title = item.get_text().strip()  # Mengambil judul artikel
        link = item['href']  # Mengambil tautan artikel
        articles.append({'title': title, 'link': link})

    # Menampilkan hasil crawling
    if articles:
        print(f"Menemukan {len(articles)} artikel tentang Pilkada:\n")
        for i, article in enumerate(articles, 1):
            print(f"{i}. {article['title']}")
            print(f"   Link: {article['link']}\n")
    else:
        print("Tidak ada artikel yang ditemukan.")
else:
    print("Failed to retrieve the page")
# Out:
# Menemukan 20 artikel tentang Pilkada:
#
# 1. KIM dan Tantangan Lokal Pilkada Serentak "Made in" Jakarta
#    Link: http://nasional.kompas.com/read/2024/09/28/12150541/kim-dan-tantangan-lokal-pilkada-serentak-made-in-jakarta
#
# 2. Suswono Buka Opsi Telaah Pajak Rumah Usai Tahu Kediaman M Natsir Dijual karena PBB Tinggi
#    Link: http://megapolitan.kompas.com/read/2024/09/28/11113251/suswono-buka-opsi-telaah-pajak-rumah-usai-tahu-kediaman-m-natsir-dijual
#
# 3. Tokoh Masyarakat hingga Mahasiswa Serukan Netralitas Penegak Hukum di Pilkada Banten 2024
#    Link: http://nasional.kompas.com/read/2024/09/28/11050461/tokoh-masyarakat-hingga-mahasiswa-serukan-netralitas-penegak-hukum-di
#
# 4. PMI Tangsel Siagakan Ambulans dan Tim Kesehatan untuk Hari Pencoblosan pada Pilkada 2024
#    Link: http://megapolitan.kompas.com/read/2024/09/28/10521001/pmi-tangsel-siagakan-ambulans-dan-tim-kesehatan-untuk-hari-pencoblosan
#
# 5. Ketum GP Ansor Serukan Pilkada Damai: Mahasiswa Jangan Abai dan Cuek
# ...

# %%
import csv
import pandas as pd

# Simpan hasil crawling ke file CSV
with open('hasil_crawling_pilkada.csv', mode='w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=['title', 'link'])
    writer.writeheader()  # Menulis header kolom
    writer.writerows(articles)  # Menulis data artikel

# %%
df = pd.read_csv('hasil_crawling_pilkada.csv')
display(df)
# Out:
#                                                 title  \
# 0   KIM dan Tantangan Lokal Pilkada Serentak "Made...
# 1   Suswono Buka Opsi Telaah Pajak Rumah Usai Tahu...
# 2   Tokoh Masyarakat hingga Mahasiswa Serukan Netr...
# 3   PMI Tangsel Siagakan Ambulans dan Tim Kesehata...
# 4   Ketum GP Ansor Serukan Pilkada Damai: Mahasisw...
# 5   Ramai-ramai Awasi Netralitas ASN pada Pilkada ...
# 6   Pilkada Kalsel, Kapolda: Jangan Ada Kampanye y...
# 7   Satpol PP Jabar Patroli Siber Selama Pilkada, ...
# 8   Bobby Nasution Bakal 4 Hari Kampanye di Tapanu...
# 9   74 TPS Rawan Banjir di Jakbar Tak Dipakai Lagi...
# 10  Andika-Hendi Dapat Dukungan Mantan Kepala Desa...
# 11  KPU Jakbar Siapkan Lokasi TPS Cadangan untuk A...
# 12  Andika Perkasa Akui Kalah "Start" Sosialisikan...
# 13  Sasar Partisipasi Pemilih Muda, KPU Adakan Nob...
# 14      KPU Buleleng Terima 2.364 Kotak Suara Pilkada
# 15  Maulan-Hakim Janji Maksimalkan Aset Daerah unt...
# ...

# %%
import requests
from bs4 import BeautifulSoup

# URL halaman yang ingin dicrawl
url = 'http://regional.kompas.com/read/2024/09/20/070510078/kpu-tetapkan-dpt-pilkada-sumbawa-374351-pemilih'

# Mengirim request ke URL dan mendapatkan halaman HTML
response = requests.get(url)

# Mengecek status code untuk memastikan permintaan berhasil
if response.status_code == 200:
    print("Berhasil mengambil halaman")
else:
    print(f"Gagal mengambil halaman. Status code: {response.status_code}")

# Parsing HTML menggunakan BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Mengambil judul artikel
judul = soup.find('h1', class_='read__title').get_text(strip=True)

# Mengambil tanggal publikasi artikel
tanggal = soup.find('div', class_='read__time').get_text(strip=True)

# Mengambil isi artikel
paragraf_list = soup.find_all('p')
isi_artikel = "\n".join([paragraf.get_text(strip=True) for paragraf in paragraf_list])

# Menampilkan hasil scraping
print(f"Judul: {judul}")
print(f"Tanggal Publikasi: {tanggal}")
print(f"Isi Artikel: \n{isi_artikel}")
# Out:
# Berhasil mengambil halaman
# Judul: KPU Tetapkan DPT Pilkada Sumbawa 374.351 Pemilih
# Tanggal Publikasi: Kompas.com- 20/09/2024, 07:05 WIB
# Isi Artikel:
# KPU Tetapkan DPT Pilkada Sumbawa 374.351 Pemilih
# Tim Redaksi
# KOMPAS.com- Komisi Pemilihan Umum (KPU) Kabupaten Sumbawa, Nusa Tenggara Barat (NTB) menetapkan daftar pemilih tetap (DPT) Pilkada 2024 sebanyak 374.351 pemilih.
# Hal itu disampaikan dalam rapat pleno terbuka rekapitulasi dan penetapan daftar pemilih tetap (DPT) tingkat Kabupaten pada pemilihan Gubernur dan Wakil Gubernur Nusa Tenggara Barat (NTB) dan pemilihan Bupati dan Wakil Bupati Sumbawa tahun 2024.
# Kegiatan berlangsung di Hotel Sernu, Kamis (19/09/2024), dihadiri Sekda Sumbawa, Kapolres, Dandim, Komisioner KPU NTB, Ketua dan AnggotaKPU Sumbawa, Komisoner Bawaslu Sumbawa.
# Baca juga:4 Paslon Bupati-Wakil Bupati Lolos Tes Kesehatan, Pilkada Sumbawa Bakal Menarik
# ...

# %% [markdown]
# #PLAY STORE

# %%
# !pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.1 MB/s eta 0:00:00
# ...

# %%
from google_play_scraper import app

# Mengambil informasi dari aplikasi menggunakan app_id
app_id = 'com.whatsapp'  # Contoh: ID aplikasi WhatsApp di Play Store
app_info = app(app_id)

# Menampilkan informasi aplikasi
print("Nama Aplikasi:", app_info['title'])
print("Deskripsi Singkat:", app_info['summary'])
print("Pengembang:", app_info['developer'])
print("Rating:", app_info['score'])
print("Jumlah Pengguna:", app_info['installs'])
print("Versi Terbaru:", app_info['version'])
print("Tanggal Update Terakhir:", app_info['updated'])
print("Harga:", app_info['price'])
print("URL Play Store:", app_info['url'])
# Out:
# Nama Aplikasi: WhatsApp Messenger
# Deskripsi Singkat: Simple. Reliable. Private.
# Pengembang: WhatsApp LLC
# Rating: 4.357135
# Jumlah Pengguna: 5,000,000,000+
# Versi Terbaru: Varies with device
# Tanggal Update Terakhir: 1730858200
# Harga: 0
# URL Play Store: https://play.google.com/store/apps/details?id=com.whatsapp&hl=en&gl=us

# %%
from google_play_scraper import Sort, reviews

# Mengambil ulasan dari aplikasi berdasarkan app_id
app_id = 'com.whatsapp'  # Contoh: ID aplikasi WhatsApp
result, continuation_token = reviews(
    app_id,
    lang='en',   # Bahasa ulasan (misalnya 'en' untuk Inggris, 'id' untuk Indonesia)
    country='us',  # Negara ulasan (misalnya 'us' untuk Amerika Serikat)
    sort=Sort.NEWEST,  # Urutkan berdasarkan ulasan terbaru
    count=10  # Jumlah ulasan yang akan diambil
)

# Menampilkan ulasan aplikasi
for review in result:
    print("User:", review['userName'])
    print("Rating:", review['score'])
    print("Ulasan:", review['content'])
    print("Tanggal:", review['at'])
    print('-' * 40)
# Out:
# User: Khaira Salum
# Rating: 5
# Ulasan: I like this up
# Tanggal: 2024-11-06 04:08:35
# ----------------------------------------
# User: Melisa Herlina
# Rating: 5
# Ulasan: Support
# Tanggal: 2024-11-06 04:08:23
# ----------------------------------------
# User: Fahim Ahmed
# Rating: 5
# Ulasan: এই অ্যাপটি ব্যবহার করে অনেক ভালো লাগছে।ওয়্যাটঅ্যাপটি অসাধারণ 😍😍😍😍
# Tanggal: 2024-11-06 04:08:21
# ----------------------------------------
# User: Pramod Pusti
# Rating: 5
# Ulasan: Supper
# Tanggal: 2024-11-06 04:08:06
# ----------------------------------------
# User: Preeti Ks
# Rating: 4
# Ulasan: Good
# Tanggal: 2024-11-06 04:07:56
# ----------------------------------------
# User: Hina Nabeel
# Rating: 1
# Ulasan: So good we can send voice message texts amazing
# Tanggal: 2024-11-06 04:07:51
# ----------------------------------------
# User: jays Palacida
# Rating: 5
# Ulasan: Great app
# Tanggal: 2024-11-06 04:07:46
# ----------------------------------------
# User: Pawan Kumar
# ...

# %%
import pandas as pd

# Membuat DataFrame dari hasil review
ps = pd.DataFrame(result)

# Menyimpan DataFrame ke file CSV
ps.to_csv('playstore_reviews.csv', index=False)

print("Data review telah disimpan ke 'playstore_reviews.csv'")
# Out:
# Data review telah disimpan ke 'playstore_reviews.csv'

# %%
ps.head()
# Out:
#                                reviewId        userName  \
# 0  415c97f9-3089-4ea8-8e9c-42aa17a4077c    Khaira Salum
# 1  7407ea77-bbc5-48c2-b784-b74d6bc7b4ed  Melisa Herlina
# 2  e8049811-2341-4356-b008-4057ae77e4b1     Fahim Ahmed
# 3  72cf6667-6631-4cf1-a232-09592aa168ed    Pramod Pusti
# 4  6cfab8ac-6a65-4356-9d8a-76aef5fb5882       Preeti Ks
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0                                     I like this up      5              0
# 1                                            Support      5              0
# 2  এই অ্যাপটি ব্যবহার করে অনেক ভালো লাগছে।ওয়্যাটঅ...      5              0
# ...

# %%
ps.shape
# Out:
# (10, 11)

# %% [markdown]
# #SOAL PRAKTIKUM
#
#
# *   Ambilah data yang berbeda dengan menerapkan implementasi dari kaggle, X, Play Store dan Kompas
